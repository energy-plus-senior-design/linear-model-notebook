# %% [markdown]
# # Building Energy Consumption - Linear Model

# %% [markdown]
# ## Setup

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math

from eplusparser.eplusparser import parse, get_zones
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LassoCV, LassoLarsCV, ElasticNetCV
from sklearn.model_selection import cross_val_score, train_test_split

np.random.seed(42)

# %%
DATA_FILE_PATH = "../OpenStudio_Models/MediumOffice_2/run/eplusout.sql"

sim_df = parse(DATA_FILE_PATH)
zone_df = get_zones(DATA_FILE_PATH)

display(sim_df.head())
display(zone_df.head())
# Out:
# VariableName Cooling:Electricity Electricity:Facility  \
# KeyValue
# TimeIndex
# 7                            0.0         6.200931e+07
# 14                           0.0         6.200931e+07
# 21                           0.0         7.846241e+07
# 28                           0.0         7.414914e+07
# 35                           0.0         6.200931e+07
#
# VariableName ExteriorLights:Electricity Fans:Electricity  Gas:Facility  \
# KeyValue
# TimeIndex
# 7                            18840654.0     0.000000e+00  4.597009e+06
# 14                           18840654.0     0.000000e+00  4.597009e+06
# 21                           18840654.0     3.725539e+06  4.597009e+06
# 28                           18840654.0     3.104616e+06  4.597009e+06
# 35                           18840654.0     0.000000e+00  4.597009e+06
#
# VariableName Heating:Electricity Heating:Gas InteriorEquipment:Electricity  \
# KeyValue
# TimeIndex
# 7                   0.000000e+00         0.0                  3.448095e+07
# 14                  0.000000e+00         0.0                  3.448095e+07
# 21                  1.272756e+07         0.0                  3.448095e+07
# 28                  9.035210e+06         0.0                  3.448095e+07
# 35                  0.000000e+00         0.0                  3.448095e+07
#
# VariableName InteriorLights:Electricity  \
# KeyValue
# TimeIndex
# 7                          8.687704e+06
# 14                         8.687704e+06
# 21                         8.687704e+06
# 28                         8.687704e+06
# 35                         8.687704e+06
#
# VariableName                                 People Air Temperature  ...  \
# KeyValue     CORE_BOTTOM ZN OFFICE WHOLEBUILDING - MD OFFICE PEOPLE  ...
# TimeIndex                                                            ...
# 7                                                           0.0      ...
# 14                                                          0.0      ...
# 21                                                          0.0      ...
# 28                                                          0.0      ...
# 35                                                          0.0      ...
#
# VariableName Zone Thermostat Heating Setpoint Temperature  \
# KeyValue                            PERIMETER_BOT_ZN_4 ZN
# TimeIndex
# 7                                               12.636237
# 14                                              12.668625
# 21                                              12.885373
# 28                                              13.033262
# 35                                              12.886336
#
# VariableName                                              \
# KeyValue     PERIMETER_MID_ZN_1 ZN PERIMETER_MID_ZN_2 ZN
# TimeIndex
# 7                        12.756805             14.009754
# 14                       12.863584             14.006175
# 21                       13.151408             14.178937
# 28                       13.373711             14.299899
# 35                       13.310278             14.166440
#
# VariableName                                              \
# KeyValue     PERIMETER_MID_ZN_3 ZN PERIMETER_MID_ZN_4 ZN
# TimeIndex
# 7                        14.065678             13.644558
# 14                       14.051729             13.687547
# 21                       14.206320             13.901863
# 28                       14.309835             14.059654
# 35                       14.183553             13.964854
#
# VariableName                                              \
# KeyValue     PERIMETER_TOP_ZN_1 ZN PERIMETER_TOP_ZN_2 ZN
# TimeIndex
# 7                        14.139550             15.364463
# 14                       14.317218             15.432506
# 21                       14.652804             15.570010
# 28                       14.950314             15.543377
# 35                       14.824546             15.519881
#
# VariableName
# KeyValue     PERIMETER_TOP_ZN_3 ZN PERIMETER_TOP_ZN_4 ZN TOPFLOOR_PLENUM ZN
# TimeIndex
# 7                        15.471957             15.016169                0.0
# 14                       15.527174             15.127795                0.0
# 21                       15.637186             15.331940                0.0
# 28                       15.578876             15.396541                0.0
# 35                       15.567345             15.362458                0.0
#
# [5 rows x 246 columns]
#                        ZoneName  RelNorth  OriginX  OriginY  OriginZ  \
# ZoneIndex
# 1                CORE_BOTTOM ZN       0.0      0.0      0.0      0.0
# 2                   CORE_MID ZN       0.0      0.0      0.0      0.0
# 3                   CORE_TOP ZN       0.0      0.0      0.0      0.0
# 4          FIRSTFLOOR_PLENUM ZN       0.0      0.0      0.0      0.0
# 5            MIDFLOOR_PLENUM ZN       0.0      0.0      0.0      0.0
#
#            CentroidX  CentroidY  CentroidZ  OfType  Multiplier  ...  MaximumZ  \
# ZoneIndex                                                       ...
# 1           24.95535    16.6369     1.3716       1         1.0  ...    2.7432
# 2           24.95535    16.6369     5.3340       1         1.0  ...    6.7056
# 3           24.95535    16.6369     9.2964       1         1.0  ...   10.6680
# 4           24.95550    16.6369     3.3528       1         1.0  ...    3.9624
# 5           24.95550    16.6369     7.3152       1         1.0  ...    7.9248
#
#            CeilingHeight       Volume  InsideConvectionAlgo  \
# ZoneIndex
# 1                 2.7432  2698.037524                     2
# 2                 2.7432  2698.037524                     2
# 3                 2.7432  2698.037524                     2
# 4                 1.2192  2024.760348                     2
# 5                 1.2192  2024.760348                     2
#
#            OutsideConvectionAlgo    FloorArea  ExtGrossWallArea  \
# ZoneIndex
# 1                              2   983.536572          0.000000
# 2                              2   983.536572          0.000000
# 3                              2   983.536572          0.000000
# 4                              2  1660.728632        202.837816
# 5                              2  1660.728632        202.837816
#
#            ExtNetWallArea  ExtWindowArea  IsPartOfTotalArea
# ZoneIndex
# 1                0.000000            0.0                  1
# 2                0.000000            0.0                  1
# 3                0.000000            0.0                  1
# 4              202.837816            0.0                  0
# 5              202.837816            0.0                  0
#
# [5 rows x 26 columns]

# %%
# Utility Functions

def plot_columns(df):
    plt.rcParams["figure.figsize"] = (18,10)
    plt.rcParams["figure.subplot.hspace"] = 0.5
    plt.rcParams["figure.subplot.wspace"] = 0.5

    _, axes = plt.subplots(math.ceil(len(df.columns)/5), 5)
    for i, column in enumerate(df):
        ax=axes[int(i/5)][i%5]
        ax.scatter(df.index,df[column])
        ax.set_title(column)

    plt.show()
    
def plot_variable(varName, df):
    plt.rcParams["figure.figsize"] = (6,4)
    ax = plt.subplot(1,1,1)
    p1, = ax.plot(df[varName])
    ax.set_xlabel("Hour")
    ax.set_ylabel(varName)
    plt.show()
    
def scale_data(df, scaler):
    return pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

def rmse_cv(model, X, y):
    rmse= np.sqrt(-cross_val_score(model, X, y, scoring="neg_mean_squared_error", cv = 5))
    return(rmse)

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### Thermostat Control Type

# %%
# Plot Thermostat control type vs Setpoints

plt.rcParams["figure.figsize"] = (18,10)
plt.rcParams["figure.subplot.hspace"] = 0.5
plt.rcParams["figure.subplot.wspace"] = 0.5
_, axes = plt.subplots(4, 5)

for i, z in enumerate(zone_df["ZoneName"]):
    ax=axes[int(i/5)][i%5]
    ax.plot(sim_df["Zone Thermostat Control Type"][z])
    ax.set_title(z)

plt.show()

# %%
# Plot Thermostat setpoints in each zone
_, axes = plt.subplots(4, 5)

for i, z in enumerate(zone_df["ZoneName"]):
    ax=axes[int(i/5)][i%5]
    
    heating_setpoint = sim_df["Zone Thermostat Heating Setpoint Temperature"][z]
    cooling_setpoint = sim_df["Zone Thermostat Cooling Setpoint Temperature"][z]
    
    ax.plot(heating_setpoint, "r", cooling_setpoint, "b")
    ax.set_title(z)

plt.show()

# %%
# Plot Thermostat setpoints in each zone
_, axes = plt.subplots(4, 5)

for i, z in enumerate(zone_df["ZoneName"]):
    ax=axes[int(i/5)][i%5]
    
    heating_setpoint = sim_df["Zone Thermostat Heating Setpoint Temperature"][z]
    cooling_setpoint = sim_df["Zone Thermostat Cooling Setpoint Temperature"][z]
    
    ax.plot(heating_setpoint, "r", cooling_setpoint, "b")
    ax.set_title(z)

plt.show()

# %%
# Plot zone temps
_, axes = plt.subplots(4, 5)

for i, z in enumerate(zone_df["ZoneName"]):
    ax=axes[int(i/5)][i%5]
    
    temps = sim_df["Zone Air Temperature"][z]
    ax.plot(temps)
    ax.set_title(z)

plt.show()

# %%
# Plot zone temps
_, axes = plt.subplots(4, 5)

for i, z in enumerate(sim_df["People Air Temperature"]):
    ax=axes[int(i/5)][i%5]
    
    temps = sim_df["People Air Temperature"][z]
    ax.plot(temps)
    ax.set_title(z)

plt.show()

# %% [markdown]
# ### Combine Multi-Index

# %%
df_zone = sim_df.copy()

# Filter out Plenum zones because they don't have control inputs
df_zone = df_zone.drop(df_zone.filter(regex='.*_PLENUM ZN').columns, axis=1)

# Average multi-index by zones
df_zone.columns = [' '.join(col).strip() for col in df_zone.columns.values]
df_zone.head()
# Out:
#            Cooling:Electricity  Electricity:Facility  \
# TimeIndex
# 7                          0.0          6.200931e+07
# 14                         0.0          6.200931e+07
# 21                         0.0          7.846241e+07
# 28                         0.0          7.414914e+07
# 35                         0.0          6.200931e+07
#
#            ExteriorLights:Electricity  Fans:Electricity  Gas:Facility  \
# TimeIndex
# 7                          18840654.0      0.000000e+00  4.597009e+06
# 14                         18840654.0      0.000000e+00  4.597009e+06
# 21                         18840654.0      3.725539e+06  4.597009e+06
# 28                         18840654.0      3.104616e+06  4.597009e+06
# 35                         18840654.0      0.000000e+00  4.597009e+06
#
#            Heating:Electricity  Heating:Gas  InteriorEquipment:Electricity  \
# TimeIndex
# 7                 0.000000e+00          0.0                   3.448095e+07
# 14                0.000000e+00          0.0                   3.448095e+07
# 21                1.272756e+07          0.0                   3.448095e+07
# 28                9.035210e+06          0.0                   3.448095e+07
# 35                0.000000e+00          0.0                   3.448095e+07
#
#            InteriorLights:Electricity  \
# TimeIndex
# 7                        8.687704e+06
# 14                       8.687704e+06
# 21                       8.687704e+06
# 28                       8.687704e+06
# 35                       8.687704e+06
#
#            People Air Temperature CORE_BOTTOM ZN OFFICE WHOLEBUILDING - MD OFFICE PEOPLE  \
# TimeIndex
# 7                                                        0.0
# 14                                                       0.0
# 21                                                       0.0
# 28                                                       0.0
# 35                                                       0.0
#
#            ...  \
# TimeIndex  ...
# 7          ...
# 14         ...
# 21         ...
# 28         ...
# 35         ...
#
#            Zone Thermostat Heating Setpoint Temperature PERIMETER_BOT_ZN_3 ZN  \
# TimeIndex
# 7                                                  12.919748
# 14                                                 12.900223
# 21                                                 13.064661
# 28                                                 13.165067
# 35                                                 12.991186
#
#            Zone Thermostat Heating Setpoint Temperature PERIMETER_BOT_ZN_4 ZN  \
# TimeIndex
# 7                                                  12.636237
# 14                                                 12.668625
# 21                                                 12.885373
# 28                                                 13.033262
# 35                                                 12.886336
#
#            Zone Thermostat Heating Setpoint Temperature PERIMETER_MID_ZN_1 ZN  \
# TimeIndex
# 7                                                  12.756805
# 14                                                 12.863584
# 21                                                 13.151408
# 28                                                 13.373711
# 35                                                 13.310278
#
#            Zone Thermostat Heating Setpoint Temperature PERIMETER_MID_ZN_2 ZN  \
# TimeIndex
# 7                                                  14.009754
# 14                                                 14.006175
# 21                                                 14.178937
# 28                                                 14.299899
# 35                                                 14.166440
#
#            Zone Thermostat Heating Setpoint Temperature PERIMETER_MID_ZN_3 ZN  \
# TimeIndex
# 7                                                  14.065678
# 14                                                 14.051729
# 21                                                 14.206320
# 28                                                 14.309835
# 35                                                 14.183553
#
#            Zone Thermostat Heating Setpoint Temperature PERIMETER_MID_ZN_4 ZN  \
# TimeIndex
# 7                                                  13.644558
# 14                                                 13.687547
# 21                                                 13.901863
# 28                                                 14.059654
# 35                                                 13.964854
#
#            Zone Thermostat Heating Setpoint Temperature PERIMETER_TOP_ZN_1 ZN  \
# TimeIndex
# 7                                                  14.139550
# 14                                                 14.317218
# 21                                                 14.652804
# 28                                                 14.950314
# 35                                                 14.824546
#
#            Zone Thermostat Heating Setpoint Temperature PERIMETER_TOP_ZN_2 ZN  \
# TimeIndex
# 7                                                  15.364463
# 14                                                 15.432506
# 21                                                 15.570010
# 28                                                 15.543377
# 35                                                 15.519881
#
#            Zone Thermostat Heating Setpoint Temperature PERIMETER_TOP_ZN_3 ZN  \
# TimeIndex
# 7                                                  15.471957
# 14                                                 15.527174
# 21                                                 15.637186
# 28                                                 15.578876
# 35                                                 15.567345
#
#            Zone Thermostat Heating Setpoint Temperature PERIMETER_TOP_ZN_4 ZN
# TimeIndex
# 7                                                  15.016169
# 14                                                 15.127795
# 21                                                 15.331940
# 28                                                 15.396541
# 35                                                 15.362458
#
# [5 rows x 219 columns]

# %%
plot_columns(df_zone)

# %% [markdown]
# ## Feature Engineering

# %%
# Feature Engineering
df_engr = df_zone.copy()

df_engr = df_engr.loc[:,~df_engr.columns.str.startswith('Zone Thermostat Control Type')]
df_engr = df_engr.loc[:,~df_engr.columns.str.startswith('People Air Temperature')]
df_engr = df_engr.loc[:,~df_engr.columns.str.startswith('Zone Predicted Sensible Load to Setpoint Heat Transfer Rate')]

# %%
# Let's normalize the entire dataframe
# Doing this over the entire data frame may not be the best but it's my first pass

standard_scaler = StandardScaler()
normalized_df = scale_data(df_engr, standard_scaler)
display(normalized_df.head())
# Out:
#    Cooling:Electricity  Electricity:Facility  ExteriorLights:Electricity  \
# 0            -0.909441             -1.134919                     0.57219
# 1            -0.909441             -1.134919                     0.57219
# 2            -0.909441             -1.053571                     0.57219
# 3            -0.909441             -1.074897                     0.57219
# 4            -0.909441             -1.134919                     0.57219
#
#    Fans:Electricity  Gas:Facility  Heating:Electricity  Heating:Gas  \
# 0         -1.195518     -0.317557            -0.384215    -0.010685
# 1         -1.195518     -0.317557            -0.384215    -0.010685
# 2         -0.922518     -0.317557            -0.259629    -0.010685
# 3         -0.968018     -0.317557            -0.295772    -0.010685
# 4         -1.195518     -0.317557            -0.384215    -0.010685
#
#    InteriorEquipment:Electricity  InteriorLights:Electricity  \
# 0                      -0.923083                   -0.796463
# 1                      -0.923083                   -0.796463
# 2                      -0.923083                   -0.796463
# 3                      -0.923083                   -0.796463
# 4                      -0.923083                   -0.796463
#
#    Pumps:Electricity  ...  \
# 0          -1.471306  ...
# 1          -1.471306  ...
# 2          -1.471306  ...
# 3          -1.471306  ...
# 4          -1.471306  ...
#
#    Zone Thermostat Heating Setpoint Temperature PERIMETER_BOT_ZN_3 ZN  \
# 0                                          -0.336336
# 1                                          -0.340110
# 2                                          -0.308322
# 3                                          -0.288912
# 4                                          -0.322526
#
#    Zone Thermostat Heating Setpoint Temperature PERIMETER_BOT_ZN_4 ZN  \
# 0                                          -0.379929
# 1                                          -0.373751
# 2                                          -0.332403
# 3                                          -0.304192
# 4                                          -0.332219
#
#    Zone Thermostat Heating Setpoint Temperature PERIMETER_MID_ZN_1 ZN  \
# 0                                          -0.257493
# 1                                          -0.236575
# 2                                          -0.180191
# 3                                          -0.136642
# 4                                          -0.149068
#
#    Zone Thermostat Heating Setpoint Temperature PERIMETER_MID_ZN_2 ZN  \
# 0                                          -0.118828
# 1                                          -0.119523
# 2                                          -0.085962
# 3                                          -0.062463
# 4                                          -0.088389
#
#    Zone Thermostat Heating Setpoint Temperature PERIMETER_MID_ZN_3 ZN  \
# 0                                          -0.097131
# 1                                          -0.099789
# 2                                          -0.070335
# 3                                          -0.050613
# 4                                          -0.074673
#
#    Zone Thermostat Heating Setpoint Temperature PERIMETER_MID_ZN_4 ZN  \
# 0                                          -0.174271
# 1                                          -0.166171
# 2                                          -0.125792
# 3                                          -0.096062
# 4                                          -0.113923
#
#    Zone Thermostat Heating Setpoint Temperature PERIMETER_TOP_ZN_1 ZN  \
# 0                                          -0.026857
# 1                                           0.007918
# 2                                           0.073601
# 3                                           0.131832
# 4                                           0.107216
#
#    Zone Thermostat Heating Setpoint Temperature PERIMETER_TOP_ZN_2 ZN  \
# 0                                           0.122445
# 1                                           0.135697
# 2                                           0.162477
# 3                                           0.157289
# 4                                           0.152714
#
#    Zone Thermostat Heating Setpoint Temperature PERIMETER_TOP_ZN_3 ZN  \
# 0                                           0.135220
# 1                                           0.145748
# 2                                           0.166723
# 3                                           0.155605
# 4                                           0.153407
#
#    Zone Thermostat Heating Setpoint Temperature PERIMETER_TOP_ZN_4 ZN
# 0                                           0.053573
# 1                                           0.074674
# 2                                           0.113265
# 3                                           0.125477
# 4                                           0.119034
#
# [5 rows x 174 columns]

# %%
# Filter out meter variables
X = normalized_df.drop([("Electricity:Facility"), ("Gas:Facility")], axis=1)
X = X.loc[:,~X.columns.str.endswith(':Electricity')]
X = X.loc[:,~X.columns.str.endswith(':Gas')]

y = normalized_df["Electricity:Facility"]

# %% [markdown]
# ### Correlation

# %%
normalized_df[normalized_df.columns].corr()['Electricity:Facility'][:]
# Out:
# Cooling:Electricity                                                   0.649884
# Electricity:Facility                                                  1.000000
# ExteriorLights:Electricity                                           -0.543202
# Fans:Electricity                                                      0.877631
# Gas:Facility                                                          0.284978
# Heating:Electricity                                                   0.432388
# Heating:Gas                                                          -0.011236
# InteriorEquipment:Electricity                                         0.821983
# InteriorLights:Electricity                                            0.820476
# Pumps:Electricity                                                     0.684457
# Schedule Value AIR VELOCITY SCHEDULE                                       NaN
# Schedule Value ALWAYS OFF DISCRETE                                         NaN
# Schedule Value ALWAYS ON CONTINUOUS                                        NaN
# Schedule Value ALWAYS ON DISCRETE                                          NaN
# Schedule Value CLOTHING SCHEDULE                                           NaN
# Schedule Value CORE_BOTTOM ZN THERMOSTAT SCHEDULE                          NaN
# Schedule Value CORE_MID ZN THERMOSTAT SCHEDULE                             NaN
# Schedule Value CORE_TOP ZN THERMOSTAT SCHEDULE                             NaN
# Schedule Value FRACTION LATENT - 0.05                                      NaN
# Schedule Value FRACTION SENSIBLE - 0.2                                     NaN
# Schedule Value MIXED WATER AT FAUCET TEMP - 110F                           NaN
# Schedule Value OFFICEMEDIUM ACTIVITY_SCH                                   NaN
# Schedule Value OFFICEMEDIUM BLDG_ELEVATORS                            0.785837
# Schedule Value OFFICEMEDIUM BLDG_EQUIP_SCH_2010                       0.796755
# Schedule Value OFFICEMEDIUM BLDG_LIGHT_SCH_2010                       0.820476
# Schedule Value OFFICEMEDIUM BLDG_OCC_SCH                              0.776922
# Schedule Value OFFICEMEDIUM BLDG_SWH_SCH                              0.837052
# Schedule Value OFFICEMEDIUM CLGSETP_SCH_NO_SETBACK                   -0.184308
# Schedule Value OFFICEMEDIUM ELEV_LIGHT_FAN_SCH_ADD_DF                 0.785837
# Schedule Value OFFICEMEDIUM EXTERIOR_LIGHTING_SCHEDULE_A              0.591938
#                                                                         ...
# Zone Thermostat Cooling Setpoint Temperature CORE_BOTTOM ZN          -0.386378
# Zone Thermostat Cooling Setpoint Temperature CORE_MID ZN             -0.261359
# Zone Thermostat Cooling Setpoint Temperature CORE_TOP ZN             -0.297276
# Zone Thermostat Cooling Setpoint Temperature PERIMETER_BOT_ZN_1 ZN   -0.362028
# Zone Thermostat Cooling Setpoint Temperature PERIMETER_BOT_ZN_2 ZN   -0.383134
# Zone Thermostat Cooling Setpoint Temperature PERIMETER_BOT_ZN_3 ZN   -0.332185
# Zone Thermostat Cooling Setpoint Temperature PERIMETER_BOT_ZN_4 ZN   -0.309015
# Zone Thermostat Cooling Setpoint Temperature PERIMETER_MID_ZN_1 ZN   -0.342536
# Zone Thermostat Cooling Setpoint Temperature PERIMETER_MID_ZN_2 ZN   -0.359775
# Zone Thermostat Cooling Setpoint Temperature PERIMETER_MID_ZN_3 ZN   -0.302794
# Zone Thermostat Cooling Setpoint Temperature PERIMETER_MID_ZN_4 ZN   -0.281612
# Zone Thermostat Cooling Setpoint Temperature PERIMETER_TOP_ZN_1 ZN   -0.353180
# Zone Thermostat Cooling Setpoint Temperature PERIMETER_TOP_ZN_2 ZN   -0.372590
# Zone Thermostat Cooling Setpoint Temperature PERIMETER_TOP_ZN_3 ZN   -0.317757
# Zone Thermostat Cooling Setpoint Temperature PERIMETER_TOP_ZN_4 ZN   -0.301455
# Zone Thermostat Heating Setpoint Temperature CORE_BOTTOM ZN           0.828512
# Zone Thermostat Heating Setpoint Temperature CORE_MID ZN              0.846834
# Zone Thermostat Heating Setpoint Temperature CORE_TOP ZN              0.826789
# Zone Thermostat Heating Setpoint Temperature PERIMETER_BOT_ZN_1 ZN    0.781733
# Zone Thermostat Heating Setpoint Temperature PERIMETER_BOT_ZN_2 ZN    0.774975
# Zone Thermostat Heating Setpoint Temperature PERIMETER_BOT_ZN_3 ZN    0.792575
# Zone Thermostat Heating Setpoint Temperature PERIMETER_BOT_ZN_4 ZN    0.789862
# Zone Thermostat Heating Setpoint Temperature PERIMETER_MID_ZN_1 ZN    0.791855
# Zone Thermostat Heating Setpoint Temperature PERIMETER_MID_ZN_2 ZN    0.779913
# Zone Thermostat Heating Setpoint Temperature PERIMETER_MID_ZN_3 ZN    0.795831
# Zone Thermostat Heating Setpoint Temperature PERIMETER_MID_ZN_4 ZN    0.795416
# Zone Thermostat Heating Setpoint Temperature PERIMETER_TOP_ZN_1 ZN    0.769466
# Zone Thermostat Heating Setpoint Temperature PERIMETER_TOP_ZN_2 ZN    0.757714
# Zone Thermostat Heating Setpoint Temperature PERIMETER_TOP_ZN_3 ZN    0.774539
# Zone Thermostat Heating Setpoint Temperature PERIMETER_TOP_ZN_4 ZN    0.774690
# Name: Electricity:Facility, Length: 174, dtype: float64

# %% [markdown]
# ## Linear Model Training & Results

# %%
model_lasso = LassoCV(alphas = [0.0001, 0.0003, 0.0006, 0.001, 0.003, 0.006, 0.01, 0.03, 0.06, 0.1,
                                0.3, 0.6, 1], max_iter = 5000, cv = 5).fit(X, y)
# Out:
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %%
rmse_cv(model_lasso, X, y).mean()
# Out:
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# 0.263337449158158

# %%
# Predictions on test dataset
# print("RMSE Error: {0}".format(rmse_cv(model_lasso).mean()))
plt.rcParams["figure.figsize"] = (6,4)
plt.plot(X.index.values, model_lasso.predict(X))

# %%
# Error in testing data
plt.plot(X.index.values, abs(y - model_lasso.predict(X)))
plt.show()

plt.plot(df_zone["Heating:Gas"])
plt.show()

# %%
coef = pd.Series(model_lasso.coef_, index = X.columns)
print("Lasso picked " + str(sum(coef != 0)) + " variables and eliminated the other " +  str(sum(coef == 0)) + " variables")
imp_coef = pd.concat([coef.sort_values().head(10),
                     coef.sort_values().tail(10)])

imp_coef.plot(kind = "barh")
plt.title("Coefficients in the Lasso Model")
# Out:
# Lasso picked 75 variables and eliminated the other 88 variables
# Text(0.5, 1.0, 'Coefficients in the Lasso Model')
