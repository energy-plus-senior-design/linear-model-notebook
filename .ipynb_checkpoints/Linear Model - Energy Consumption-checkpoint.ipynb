# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math

from eplusparser.eplusparser import parse, get_zones
from sklearn.preprocessing import StandardScaler

# %%
DATA_FILE_PATH = "../OpenStudio_Models/MediumOffice_2/run/eplusout.sql"

sim_df = parse(DATA_FILE_PATH)
zone_df = get_zones(DATA_FILE_PATH)

display(sim_df.head())
display(zone_df.head())
# Out:
# VariableName Cooling:Electricity Electricity:Facility  \
# KeyValue
# TimeIndex
# 7                            0.0         6.200931e+07
# 14                           0.0         6.200931e+07
# 21                           0.0         6.200931e+07
# 28                           0.0         6.200931e+07
# 35                           0.0         6.200931e+07
#
# VariableName ExteriorLights:Electricity Fans:Electricity  Gas:Facility  \
# KeyValue
# TimeIndex
# 7                            18840654.0              0.0  4.597009e+06
# 14                           18840654.0              0.0  4.597009e+06
# 21                           18840654.0              0.0  4.597009e+06
# 28                           18840654.0              0.0  4.597009e+06
# 35                           18840654.0              0.0  4.597009e+06
#
# VariableName Heating:Electricity Heating:Gas InteriorEquipment:Electricity  \
# KeyValue
# TimeIndex
# 7                            0.0         0.0                  3.448095e+07
# 14                           0.0         0.0                  3.448095e+07
# 21                           0.0         0.0                  3.448095e+07
# 28                           0.0         0.0                  3.448095e+07
# 35                           0.0         0.0                  3.448095e+07
#
# VariableName InteriorLights:Electricity Pumps:Electricity  ...  \
# KeyValue                                                   ...
# TimeIndex                                                  ...
# 7                          8.687704e+06               0.0  ...
# 14                         8.687704e+06               0.0  ...
# 21                         8.687704e+06               0.0  ...
# 28                         8.687704e+06               0.0  ...
# 35                         8.687704e+06               0.0  ...
#
# VariableName Zone Thermostat Heating Setpoint Temperature  \
# KeyValue                            PERIMETER_BOT_ZN_4 ZN
# TimeIndex
# 7                                                    15.6
# 14                                                   15.6
# 21                                                   15.6
# 28                                                   15.6
# 35                                                   15.6
#
# VariableName                                              \
# KeyValue     PERIMETER_MID_ZN_1 ZN PERIMETER_MID_ZN_2 ZN
# TimeIndex
# 7                             15.6                  15.6
# 14                            15.6                  15.6
# 21                            15.6                  15.6
# 28                            15.6                  15.6
# 35                            15.6                  15.6
#
# VariableName                                              \
# KeyValue     PERIMETER_MID_ZN_3 ZN PERIMETER_MID_ZN_4 ZN
# TimeIndex
# 7                             15.6                  15.6
# 14                            15.6                  15.6
# 21                            15.6                  15.6
# 28                            15.6                  15.6
# 35                            15.6                  15.6
#
# VariableName                                              \
# KeyValue     PERIMETER_TOP_ZN_1 ZN PERIMETER_TOP_ZN_2 ZN
# TimeIndex
# 7                             15.6                  15.6
# 14                            15.6                  15.6
# 21                            15.6                  15.6
# 28                            15.6                  15.6
# 35                            15.6                  15.6
#
# VariableName
# KeyValue     PERIMETER_TOP_ZN_3 ZN PERIMETER_TOP_ZN_4 ZN TOPFLOOR_PLENUM ZN
# TimeIndex
# 7                             15.6                  15.6                0.0
# 14                            15.6                  15.6                0.0
# 21                            15.6                  15.6                0.0
# 28                            15.6                  15.6                0.0
# 35                            15.6                  15.6                0.0
#
# [5 rows x 231 columns]
#                        ZoneName  RelNorth  OriginX  OriginY  OriginZ  \
# ZoneIndex
# 1                CORE_BOTTOM ZN       0.0      0.0      0.0      0.0
# 2                   CORE_MID ZN       0.0      0.0      0.0      0.0
# 3                   CORE_TOP ZN       0.0      0.0      0.0      0.0
# 4          FIRSTFLOOR_PLENUM ZN       0.0      0.0      0.0      0.0
# 5            MIDFLOOR_PLENUM ZN       0.0      0.0      0.0      0.0
#
#            CentroidX  CentroidY  CentroidZ  OfType  Multiplier  ...  MaximumZ  \
# ZoneIndex                                                       ...
# 1           24.95535    16.6369     1.3716       1         1.0  ...    2.7432
# 2           24.95535    16.6369     5.3340       1         1.0  ...    6.7056
# 3           24.95535    16.6369     9.2964       1         1.0  ...   10.6680
# 4           24.95550    16.6369     3.3528       1         1.0  ...    3.9624
# 5           24.95550    16.6369     7.3152       1         1.0  ...    7.9248
#
#            CeilingHeight       Volume  InsideConvectionAlgo  \
# ZoneIndex
# 1                 2.7432  2698.037524                     2
# 2                 2.7432  2698.037524                     2
# 3                 2.7432  2698.037524                     2
# 4                 1.2192  2024.760348                     2
# 5                 1.2192  2024.760348                     2
#
#            OutsideConvectionAlgo    FloorArea  ExtGrossWallArea  \
# ZoneIndex
# 1                              2   983.536572          0.000000
# 2                              2   983.536572          0.000000
# 3                              2   983.536572          0.000000
# 4                              2  1660.728632        202.837816
# 5                              2  1660.728632        202.837816
#
#            ExtNetWallArea  ExtWindowArea  IsPartOfTotalArea
# ZoneIndex
# 1                0.000000            0.0                  1
# 2                0.000000            0.0                  1
# 3                0.000000            0.0                  1
# 4              202.837816            0.0                  0
# 5              202.837816            0.0                  0
#
# [5 rows x 26 columns]

# %%
def plot_columns(df):
    plt.rcParams["figure.figsize"] = (18,10)
    plt.rcParams["figure.subplot.hspace"] = 0.5
    plt.rcParams["figure.subplot.wspace"] = 0.5

    _, axes = plt.subplots(math.ceil(len(df.columns)/5), 5)
    for i, column in enumerate(df):
        ax=axes[int(i/5)][i%5]
        ax.plot(df[column])
        ax.set_title(column)

    plt.show()

# %%
# Plot Thermostat control type vs Setpoints

for z in zone_df["ZoneName"]:
    plt.rcParams["figure.figsize"] = (18,10)
    plt.rcParams["figure.subplot.hspace"] = 0.5
    plt.rcParams["figure.subplot.wspace"] = 0.5

    _, axes = plt.subplots(5, 5)
    for i, column in enumerate(df_zone):
        ax=axes[int(i/5)][i%5]
        ax.plot(df_zone[column])
        ax.set_title(column)

    plt.show()
# Out:
# {'', 'AIR VELOCITY SCHEDULE', 'OFFICEMEDIUM CLGSETP_SCH_NO_SETBACK', 'OFFICEMEDIUM INFIL_DOOR_OPENING_SCH', 'PERIMETER_BOT_ZN_2 ZN', 'PERIMETER_TOP_ZN_2 ZN', 'CORE_TOP ZN THERMOSTAT SCHEDULE', 'PERIMETER_MID_ZN_4 ZN', 'WORK EFFICIENCY SCHEDULE', 'OFFICEMEDIUM BLDG_SWH_SCH', 'CORE_BOTTOM ZN THERMOSTAT SCHEDULE', 'SUPPLY AIR TEMP - 55.0F 2', 'PERIMETER_BOT_ZN_3 ZN', 'CORE_TOP ZN', 'PERIMETER_BOT_ZN_1 ZN', 'OFFICEMEDIUM INFIL_SCH_PNNL', 'OFFICEMEDIUM EXTERIOR_LIGHTING_SCHEDULE_A', 'PERIMETER_MID_ZN_4 ZN THERMOSTAT SCHEDULE', 'SUPPLY AIR TEMP - 55.0F', 'PERIMETER_BOT_ZN_4 ZN', 'PERIMETER_TOP_ZN_1 ZN', 'SUPPLY AIR TEMP - 55.0F 1', 'SERVICE WATER LOOP TEMP - 140F', 'PERIMETER_TOP_ZN_3 ZN', 'PERIMETER_TOP_ZN_2 ZN THERMOSTAT SCHEDULE', 'OFFICEMEDIUM HTGSETP_SCH_PACU_VAV_BOT', 'OFFICEMEDIUM BLDG_OCC_SCH', 'PERIMETER_TOP_ZN_4 ZN THERMOSTAT SCHEDULE', 'PERIMETER_BOT_ZN_2 ZN THERMOSTAT SCHEDULE', 'PERIMETER_MID_ZN_3 ZN', 'PERIMETER_BOT_ZN_4 ZN THERMOSTAT SCHEDULE', 'OFFICEMEDIUM HVACOPERATIONSCHD', 'OFFICEMEDIUM BLDG_ELEVATORS', 'MIXED WATER AT FAUCET TEMP - 110F', 'OFFICEMEDIUM ACTIVITY_SCH', 'OFFICEMEDIUM EXTERIOR_LIGHTING_SCHEDULE_B', 'PERIMETER_BOT_ZN_3 ZN THERMOSTAT SCHEDULE', 'OFFICEMEDIUM MINOA_MOTORIZEDDAMPER_SCHED', 'OFFICEMEDIUM BLDG_EQUIP_SCH_2010', 'PERIMETER_TOP_ZN_1 ZN THERMOSTAT SCHEDULE', 'FRACTION SENSIBLE - 0.2', 'PERIMETER_MID_ZN_2 ZN', 'PERIMETER_TOP_ZN_4 ZN', 'CLOTHING SCHEDULE', 'PERIMETER_MID_ZN_3 ZN THERMOSTAT SCHEDULE', 'PERIMETER_TOP_ZN_3 ZN THERMOSTAT SCHEDULE', 'CORE_BOTTOM ZN', 'ALWAYS OFF DISCRETE', 'OFFICEMEDIUM BLDG_LIGHT_SCH_2010', 'OFFICEMEDIUM ELEV_LIGHT_FAN_SCH_ADD_DF', 'CORE_MID ZN', 'FIRSTFLOOR_PLENUM ZN', 'CORE_MID ZN THERMOSTAT SCHEDULE', 'ALWAYS ON CONTINUOUS', 'PERIMETER_MID_ZN_1 ZN', 'MIDFLOOR_PLENUM ZN', 'PERIMETER_BOT_ZN_1 ZN THERMOSTAT SCHEDULE', 'FRACTION LATENT - 0.05', 'ALWAYS ON DISCRETE', 'PERIMETER_MID_ZN_1 ZN THERMOSTAT SCHEDULE', 'TOPFLOOR_PLENUM ZN', 'PERIMETER_MID_ZN_2 ZN THERMOSTAT SCHEDULE'}

# %%
# Change this variable to control what columns are used

df_zone = df.copy()
df_sched = df_zone['Schedule Value'].filter(regex='OFFICEMEDIUM.*', axis=1)
del df_zone['Schedule Value']

df_zone.columns = df_zone.columns.get_level_values(0)
df_zone = df_zone.groupby(lambda x:x, axis=1).mean()

df_mean = df_zone.join(df_sched)
df_mean.head()
# print(f'Variables used: {set(df_mean.columns)}')
# Out:
#            Cooling:Electricity  Electricity:Facility  \
# TimeIndex
# 7                          0.0          6.200931e+07
# 14                         0.0          6.200931e+07
# 21                         0.0          6.200931e+07
# 28                         0.0          6.200931e+07
# 35                         0.0          6.200931e+07
#
#            ExteriorLights:Electricity  Fans:Electricity  Gas:Facility  \
# TimeIndex
# 7                          18840654.0               0.0  4.597009e+06
# 14                         18840654.0               0.0  4.597009e+06
# 21                         18840654.0               0.0  4.597009e+06
# 28                         18840654.0               0.0  4.597009e+06
# 35                         18840654.0               0.0  4.597009e+06
#
#            Heating:Electricity  Heating:Gas  InteriorEquipment:Electricity  \
# TimeIndex
# 7                          0.0          0.0                   3.448095e+07
# 14                         0.0          0.0                   3.448095e+07
# 21                         0.0          0.0                   3.448095e+07
# 28                         0.0          0.0                   3.448095e+07
# 35                         0.0          0.0                   3.448095e+07
#
#            InteriorLights:Electricity  Pumps:Electricity  ...  \
# TimeIndex                                                 ...
# 7                        8.687704e+06                0.0  ...
# 14                       8.687704e+06                0.0  ...
# 21                       8.687704e+06                0.0  ...
# 28                       8.687704e+06                0.0  ...
# 35                       8.687704e+06                0.0  ...
#
#            OFFICEMEDIUM BLDG_SWH_SCH  OFFICEMEDIUM CLGSETP_SCH_NO_SETBACK  \
# TimeIndex
# 7                                0.0                                 24.0
# 14                               0.0                                 24.0
# 21                               0.0                                 24.0
# 28                               0.0                                 24.0
# 35                               0.0                                 24.0
#
#            OFFICEMEDIUM ELEV_LIGHT_FAN_SCH_ADD_DF  \
# TimeIndex
# 7                                             0.0
# 14                                            0.0
# 21                                            0.0
# 28                                            0.0
# 35                                            0.0
#
#            OFFICEMEDIUM EXTERIOR_LIGHTING_SCHEDULE_A  \
# TimeIndex
# 7                                                0.0
# 14                                               0.0
# 21                                               0.0
# 28                                               0.0
# 35                                               0.0
#
#            OFFICEMEDIUM EXTERIOR_LIGHTING_SCHEDULE_B  \
# TimeIndex
# 7                                                0.7
# 14                                               0.7
# 21                                               0.7
# 28                                               0.7
# 35                                               0.7
#
#            OFFICEMEDIUM HTGSETP_SCH_PACU_VAV_BOT  \
# TimeIndex
# 7                                           15.6
# 14                                          15.6
# 21                                          15.6
# 28                                          15.6
# 35                                          15.6
#
#            OFFICEMEDIUM HVACOPERATIONSCHD  \
# TimeIndex
# 7                                     0.0
# 14                                    0.0
# 21                                    0.0
# 28                                    0.0
# 35                                    0.0
#
#            OFFICEMEDIUM INFIL_DOOR_OPENING_SCH  OFFICEMEDIUM INFIL_SCH_PNNL  \
# TimeIndex
# 7                                          0.0                          1.0
# 14                                         0.0                          1.0
# 21                                         0.0                          1.0
# 28                                         0.0                          1.0
# 35                                         0.0                          1.0
#
#            OFFICEMEDIUM MINOA_MOTORIZEDDAMPER_SCHED
# TimeIndex
# 7                                               0.0
# 14                                              0.0
# 21                                              0.0
# 28                                              0.0
# 35                                              0.0
#
# [5 rows x 36 columns]

# %%
plot_columns(df_zone)

# %%
plot_columns(df_sched)

# %%
def plot_variable(varName, df):
    plt.rcParams["figure.figsize"] = (6,4)
    ax = plt.subplot(1,1,1)
    p1, = ax.plot(df[varName])
    ax.set_xlabel("Hour")
    ax.set_ylabel(varName)
    plt.show()
    
def scale_data(df, scaler):
    return pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %%
# Feature Engineering

df_engr = df_mean.copy()
df_engr["Zone_Temperature_Diff"] = df_engr["Zone "]

# %%
plot_variable("")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-a5ee0a5485fb> in <module>
# ----> 1 plot_variable("")
#
# TypeError: plot_variable() missing 1 required positional argument: 'df'

# %%
# Let's normalize the entire dataframe
# Doing this over the entire data frame may not be the best but it's my first pass

standard_scaler = StandardScaler()
normalized_df = scale_data(df_mean, standard_scaler)
display(normalized_df.head())
# Out:
#    Cooling:Electricity  Electricity:Facility  ExteriorLights:Electricity  \
# 0            -0.957288             -1.143706                     0.57219
# 1            -0.957288             -1.143706                     0.57219
# 2            -0.957288             -1.143706                     0.57219
# 3            -0.957288             -1.143706                     0.57219
# 4            -0.957288             -1.143706                     0.57219
#
#    Fans:Electricity  Gas:Facility  Heating:Electricity  Heating:Gas  \
# 0         -1.187378     -0.226263            -0.339284     -0.09255
# 1         -1.187378     -0.226263            -0.339284     -0.09255
# 2         -1.187378     -0.226263            -0.339284     -0.09255
# 3         -1.187378     -0.226263            -0.339284     -0.09255
# 4         -1.187378     -0.226263            -0.339284     -0.09255
#
#    InteriorEquipment:Electricity  InteriorLights:Electricity  \
# 0                      -0.923083                   -0.796463
# 1                      -0.923083                   -0.796463
# 2                      -0.923083                   -0.796463
# 3                      -0.923083                   -0.796463
# 4                      -0.923083                   -0.796463
#
#    Pumps:Electricity  ...  OFFICEMEDIUM BLDG_SWH_SCH  \
# 0          -1.471306  ...                  -0.932576
# 1          -1.471306  ...                  -0.932576
# 2          -1.471306  ...                  -0.932576
# 3          -1.471306  ...                  -0.932576
# 4          -1.471306  ...                  -0.932576
#
#    OFFICEMEDIUM CLGSETP_SCH_NO_SETBACK  \
# 0                            -0.176688
# 1                            -0.176688
# 2                            -0.176688
# 3                            -0.176688
# 4                            -0.176688
#
#    OFFICEMEDIUM ELEV_LIGHT_FAN_SCH_ADD_DF  \
# 0                               -0.755027
# 1                               -0.755027
# 2                               -0.755027
# 3                               -0.755027
# 4                               -0.755027
#
#    OFFICEMEDIUM EXTERIOR_LIGHTING_SCHEDULE_A  \
# 0                                  -1.732051
# 1                                  -1.732051
# 2                                  -1.732051
# 3                                  -1.732051
# 4                                  -1.732051
#
#    OFFICEMEDIUM EXTERIOR_LIGHTING_SCHEDULE_B  \
# 0                                  -1.732051
# 1                                  -1.732051
# 2                                  -1.732051
# 3                                  -1.732051
# 4                                  -1.732051
#
#    OFFICEMEDIUM HTGSETP_SCH_PACU_VAV_BOT  OFFICEMEDIUM HVACOPERATIONSCHD  \
# 0                              -1.106499                       -1.096914
# 1                              -1.106499                       -1.096914
# 2                              -1.106499                       -1.096914
# 3                              -1.106499                       -1.096914
# 4                              -1.106499                       -1.096914
#
#    OFFICEMEDIUM INFIL_DOOR_OPENING_SCH  OFFICEMEDIUM INFIL_SCH_PNNL  \
# 0                            -0.472368                     1.096914
# 1                            -0.472368                     1.096914
# 2                            -0.472368                     1.096914
# 3                            -0.472368                     1.096914
# 4                            -0.472368                     1.096914
#
#    OFFICEMEDIUM MINOA_MOTORIZEDDAMPER_SCHED
# 0                                  -1.02123
# 1                                  -1.02123
# 2                                  -1.02123
# 3                                  -1.02123
# 4                                  -1.02123
#
# [5 rows x 36 columns]

# %%
from sklearn.linear_model import LassoCV, LassoLarsCV, ElasticNetCV
from sklearn.model_selection import cross_val_score, train_test_split

def rmse_cv(model, X, y):
    rmse= np.sqrt(-cross_val_score(model, X, y, scoring="neg_mean_squared_error", cv = 5))
    return(rmse)


X = normalized_df.drop([("Electricity:Facility"), ("Gas:Facility")], axis=1)
X = X.loc[:,~X.columns.str.endswith(':Electricity')]
X = X.loc[:,~X.columns.str.endswith(':Gas')]

y = normalized_df["Electricity:Facility"]

# %%
model_lasso = LassoCV(cv=5).fit(X, y)

# %%
rmse_cv(model_lasso, X, y).mean()
# Out:
# 0.3643674511194005

# %%
# Predictions on test dataset
# print("RMSE Error: {0}".format(rmse_cv(model_lasso).mean()))
plt.rcParams["figure.figsize"] = (6,4)
plt.plot(X.index.values, model_lasso.predict(X))

# %%
# Error in testing data
plt.plot(X.index.values, abs(y - model_lasso.predict(X)))

# %%
coef = pd.Series(model_lasso.coef_, index = X.columns)
print("Lasso picked " + str(sum(coef != 0)) + " variables and eliminated the other " +  str(sum(coef == 0)) + " variables")
imp_coef = pd.concat([coef.sort_values().head(10),
                     coef.sort_values().tail(10)])

imp_coef.plot(kind = "barh")
plt.title("Coefficients in the Lasso Model")
# Out:
# Lasso picked 17 variables and eliminated the other 8 variables
# Text(0.5, 1.0, 'Coefficients in the Lasso Model')
